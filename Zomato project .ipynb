# %%
#Importing the libraries

import pandas as pd
import numpy as np

#visualization 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing the database

dataset = pd.read_csv("C:/Users/Administrator/Downloads/zomato.csv")

# %%
dataset
# Out:
#       Unnamed: 0.1  Unnamed: 0         restaurant name     restaurant type  \
# 0                0           0            #FeelTheROLL         Quick Bites
# 1                1           1              #L-81 Cafe         Quick Bites
# 2                2           2                 #refuel                Cafe
# 3                3           3      '@ Biryani Central       Casual Dining
# 4                4           4              '@ The Bbq       Casual Dining
# ...            ...         ...                     ...                 ...
# 7100          7100        7100                  Zoey's                Cafe
# 7101          7101        7101  ZOROY Luxury Chocolate      Dessert Parlor
# 7102          7102        7102       Zu's Doner Kebaps  Takeaway, Delivery
# 7103          7103        7103                   Zyara       Casual Dining
# 7104          7104        7104                  Zyksha          Food Truck
#
# ...

# %%
#Delete unwanted column

dataset.drop('Unnamed: 0.1',axis = 1, inplace = True)
dataset
# Out:
#       Unnamed: 0         restaurant name     restaurant type  rate (out of 5)  \
# 0              0            #FeelTheROLL         Quick Bites              3.4
# 1              1              #L-81 Cafe         Quick Bites              3.9
# 2              2                 #refuel                Cafe              3.7
# 3              3      '@ Biryani Central       Casual Dining              2.7
# 4              4              '@ The Bbq       Casual Dining              2.8
# ...          ...                     ...                 ...              ...
# 7100        7100                  Zoey's                Cafe              4.3
# 7101        7101  ZOROY Luxury Chocolate      Dessert Parlor              4.0
# 7102        7102       Zu's Doner Kebaps  Takeaway, Delivery              3.7
# 7103        7103                   Zyara       Casual Dining              3.8
# 7104        7104                  Zyksha          Food Truck              3.4
#
# ...

# %%
# shape

dataset.shape
# Out:
# (7105, 11)

# %%
# It is also a good practice to know the columns and their corresponding data types
# along with finding whether they contain null values or not.

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7105 entries, 0 to 7104
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             7105 non-null   int64
#  1   restaurant name        7105 non-null   object
#  2   restaurant type        7105 non-null   object
#  3   rate (out of 5)        7037 non-null   float64
#  4   num of ratings         7105 non-null   int64
#  5   avg cost (two people)  7048 non-null   float64
#  6   online_order           7105 non-null   object
#  7   table booking          7105 non-null   object
#  8   cuisines type          7105 non-null   object
#  9   area                   7105 non-null   object
#  10  local address          7105 non-null   object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 610.7+ KB

# %% [markdown]
# # We can see that the dataset contains 11 columns and 7105 rows.
#
# * The columns are as follows:
#
# 1. Unnamed: 0
#
# 2. restaurant name
#
# 3. restaurant type
#
# 4. rate (out of 5)
#
# 5. num of ratings
#
# 6. avg cost (two people)
#
# 7. online_order
#
# 8. table booking
#
# 9. cuisines type
#
# 12. area
#
# 13. local address
#
# * The data types of the columns are as follows:
#
# 1. Unnamed: 0                    -int64
#
# 2. restaurant name               -object
#
# 3. restaurant type               -object
#
# 4. rate (out of 5)               -float64
#
# 5. num of ratings                -int64
#
# 6. avg cost (two people)         -float64
#
# 7. online_order                  -object
#
# 8. table booking                 -object
#
# 9. cuisines type                 -object
#
# 12. area                         -object
#
# 13. local address                -object

# %%
# We can also see that the column restaurant name is of object data type, but it is actually a string.
# We can convert it to a string using the following code:
dataset['restaurant name']=dataset['restaurant name'].astype(str)

# %%
# We can also see that the column restaurant type is of object data type, but it is actually a string.
# We can convert it to a string using the following code:
dataset['restaurant type']=dataset['restaurant type'].astype(str)

# %%
# We can also see that the column online_order is of object data type, but it is actually a string.
# We can convert it to a string using the following code:
dataset['online_order']=dataset['online_order'].astype(str)

# %%
# We can also see that the column table booking is of object data type, but it is actually a string.
# We can convert it to a string using the following code:
dataset['table booking']=dataset['table booking'].astype(str)

# %%
# We can also see that the column cuisines type is of object data type, but it is actually a string.
# We can convert it to a string using the following code:
dataset['cuisines type']=dataset['cuisines type'].astype(str)

# %%
# We can also see that the column area is of object data type, but it is actually a string.
# We can convert it to a string using the following code:
dataset['area']=dataset['area'].astype(str)

# %%
# We can also see that the column local address is of object data type, but it is actually a string.
# We can convert it to a string using the following code:
dataset['local address']=dataset['local address'].astype(str)

# %%
# to get a better understanding of the dataset,
# we can also see the statistical summary of the dataset.
dataset.describe()
# Out:
#         Unnamed: 0  rate (out of 5)  num of ratings  avg cost (two people)
# count  7105.000000      7037.000000     7105.000000            7048.000000
# mean   3552.000000         3.514253      188.921042             540.286464
# std    2051.181164         0.463249      592.171049             462.902305
# min       0.000000         1.800000        1.000000              40.000000
# 25%    1776.000000         3.200000       16.000000             300.000000
# 50%    3552.000000         3.500000       40.000000             400.000000
# 75%    5328.000000         3.800000      128.000000             600.000000
# max    7104.000000         4.900000    16345.000000            6000.000000

# %% [markdown]
# # the statistical summary of the dataset gives us the following information:
#
#  1. The mean rate(out of 5) is 3.5 and the number of rating mean is 188.92.
#
#  2. The minimum rate(out of 5) is 1.8 and the number of rating minimum is 1.
#
#  3. The maximum rate(out of 5) is 4.9 and the number of rating maximum is 16345.
#
#  4. The standrad deviation of the rate(out of 5) is 0.4 and the number of rating standrad deviation is 592.1.
#
#  5. The 25th percentile of the rate(out of 5) is 3.2.
#
#  6. The 50th percentile of the rate(out of 5) is 3.5.
#
#  7. The 75th percentile of the rate(out of 5) is 3.8.

# %%
# We can also see the number of unique users and items in the dataset.
dataset.nunique()
# Out:
# Unnamed: 0               7105
# restaurant name          7105
# restaurant type            81
# rate (out of 5)            31
# num of ratings            935
# avg cost (two people)      65
# online_order                2
# table booking               2
# cuisines type            2175
# area                       30
# local address              90
# dtype: int64

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'restaurant name', 'restaurant type', 'rate (out of 5)',
#        'num of ratings', 'avg cost (two people)', 'online_order',
#        'table booking', 'cuisines type', 'area', 'local address'],
#       dtype='object')

# %%
len(dataset.columns)
# Out:
# 11

# %%
# check for duplicates
dataset.duplicated().sum()
# Out:
# np.int64(0)

# %%
# check for missing values
dataset.isna().sum()
# Out:
# Unnamed: 0                0
# restaurant name           0
# restaurant type           0
# rate (out of 5)          68
# num of ratings            0
# avg cost (two people)    57
# online_order              0
# table booking             0
# cuisines type             0
# area                      0
# local address             0
# dtype: int64

# %%
#which rates of highest count
sns.countplot(x='rate (out of 5)', data=dataset.head(20))
# Out:
# <Axes: xlabel='rate (out of 5)', ylabel='count'>

# %%
# total count of Rating out of 5
plt.hist(dataset['rate (out of 5)'])
# Out:
# (array([   8.,   25.,  130., 1122., 1248., 1599., 1655.,  879.,  320.,
#           51.]),
#  array([1.8 , 2.11, 2.42, 2.73, 3.04, 3.35, 3.66, 3.97, 4.28, 4.59, 4.9 ]),
#  <BarContainer object of 10 artists>)

# %%
#count of avg cost (two people)
Two_peoples = dataset['avg cost (two people)']
sns.countplot(x = Two_peoples)
# Out:
# <Axes: xlabel='avg cost (two people)', ylabel='count'>

# %%
#total number of rating
plt.hist(dataset['num of ratings'])
# Out:
# (array([6.96e+03, 1.00e+02, 2.60e+01, 6.00e+00, 8.00e+00, 2.00e+00,
#         1.00e+00, 0.00e+00, 0.00e+00, 2.00e+00]),
#  array([1.00000e+00, 1.63540e+03, 3.26980e+03, 4.90420e+03, 6.53860e+03,
#         8.17300e+03, 9.80740e+03, 1.14418e+04, 1.30762e+04, 1.47106e+04,
#         1.63450e+04]),
#  <BarContainer object of 10 artists>)

# %%
#numbers of rating and rate out of 5 
dataset.groupby('rate (out of 5)')['num of ratings'].count().sort_values(ascending=True).head(10).plot(kind='pie',autopct='%1.2f%%')
# Out:
# <Axes: ylabel='num of ratings'>

# %%
#total online orders by cuisines type
dataset[dataset['online_order']=='Yes'].groupby('online_order')['cuisines type'].count().plot(kind='bar')
# Out:
# <Axes: xlabel='online_order'>

# %%
#number of restaurants by location
restaurant_by_area = dataset['area'].value_counts()
restaurant_by_area.plot(kind='bar')
# Out:
# <Axes: xlabel='area'>

# %%
#Average rating by location
ave_rating_by_location = dataset.groupby('area')['rate (out of 5)'].mean().sort_values(ascending = False)
ave_rating_by_location.plot(kind='bar')
# Out:
# <Axes: xlabel='area'>

# %%
#count(Distribution) of the restaurant type
restaurant_type_counts= dataset['restaurant type'].value_counts().head(10)
restaurant_type_counts.plot(kind='bar')
# Out:
# <Axes: xlabel='restaurant type'>

# %%
#online orders
online_order = dataset['online_order'].value_counts()
online_order.plot(kind='bar')
# Out:
# <Axes: xlabel='online_order'>

# %%
#tables bookings
table_bookings = dataset['table booking'].value_counts()
table_bookings.plot(kind='bar')
# Out:
# <Axes: xlabel='table booking'>

# %%
#count of online orders and offline orders
online_order.plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>
